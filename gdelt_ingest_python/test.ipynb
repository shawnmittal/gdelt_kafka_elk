# %%
import os
import zipfile
import requests
import sys
import datetime
import csv
import json
from kafka import KafkaProducer
from kafka.errors import KafkaError
from gdeltconfig import *

# %%
# create instance of kafka producer
host = 'localhost:9092'
producer = KafkaProducer(bootstrap_servers=[host], value_serializer=lambda m: json.dumps(m).encode('ascii'))

# %%
event = {
    "@timestamp": [
        "2023-03-06T22:25:41.181Z"
    ],
    "@version": [
        "1"
    ],
    "ActionGeo_ADM1Code": [
        "GT"
    ],
    "ActionGeo_ADM2Code": [
        ""
    ],
    "ActionGeo_CountryCode": [
        "GT"
    ],
    "ActionGeo_FeatureID": [
        "GT"
    ],
    "ActionGeo_Fullname": [
        "Guatemala"
    ],
    "ActionGeo_Lat": [
        15.5
    ],
    "ActionGeo_Location": [
        {
        "coordinates": [
            -90.25,
            15.5
        ],
        "type": "Point"
        }
    ],
    "ActionGeo_Long": [
        -90.25
    ],
    "ActionGeo_Type": [
        1
    ],
    "Actor1Code": [
        "myn"
    ],
    "Actor1CountryCode": [
        ""
    ],
    "Actor1EthnicCode": [
        "myn"
    ],
    "Actor1EthnicCode.keyword": [
        "myn"
    ],
    "Actor1Geo_ADM1Code": [
        "GT"
    ],
    "Actor1Geo_ADM2Code": [
        ""
    ],
    "Actor1Geo_ADM2Code.keyword": [
        ""
    ],
    "Actor1Geo_CountryCode": [
        "GT"
    ],
    "Actor1Geo_FeatureID": [
        "GT"
    ],
    "Actor1Geo_Fullname": [
        "Guatemala"
    ],
    "Actor1Geo_Lat": [
        15.5
    ],
    "Actor1Geo_Location": [
        {
        "coordinates": [
            -90.25,
            15.5
        ],
        "type": "Point"
        }
    ],
    "Actor1Geo_Long": [
        -90.25
    ],
    "Actor1Geo_Type": [
        1
    ],
    "Actor1KnownGroupCode": [
        ""
    ],
    "Actor1Name": [
        "MAYAN"
    ],
    "Actor1Religion1Code": [
        ""
    ],
    "Actor1Religion2Code": [
        ""
    ],
    "Actor1Type1Code": [
        ""
    ],
    "Actor1Type2Code": [
        ""
    ],
    "Actor1Type3Code": [
        ""
    ],
    "Actor2Code": [
        ""
    ],
    "Actor2CountryCode": [
        ""
    ],
    "Actor2EthnicCode": [
        ""
    ],
    "Actor2Geo_ADM1Code": [
        ""
    ],
    "Actor2Geo_ADM2Code": [
        ""
    ],
    "Actor2Geo_CountryCode": [
        ""
    ],
    "Actor2Geo_FeatureID": [
        ""
    ],
    "Actor2Geo_Fullname": [
        ""
    ],
    "Actor2Geo_Lat": [
        ""
    ],
    "Actor2Geo_Long": [
        ""
    ],
    "Actor2Geo_Type": [
        0
    ],
    "Actor2KnownGroupCode": [
        ""
    ],
    "Actor2Name": [
        ""
    ],
    "Actor2Religion1Code": [
        ""
    ],
    "Actor2Religion2Code": [
        ""
    ],
    "Actor2Type1Code": [
        ""
    ],
    "Actor2Type2Code": [
        ""
    ],
    "Actor2Type3Code": [
        ""
    ],
    "AvgTone": [
        -4.15667466027178
    ],
    "DATEADDED": [
        "2023-03-06T22:15:00.000Z"
    ],
    "Day": [
        "20230306"
    ],
    "event.original": [
        "{\"GlobalEventID\": \"1088025774\", \"Day\": \"20230306\", \"MonthYear\": \"202303\", \"Year\": \"2023\", \"FractionDate\": \"2023.1808\", \"Actor1Code\": \"myn\", \"Actor1Name\": \"MAYAN\", \"Actor1CountryCode\": \"\", \"Actor1KnownGroupCode\": \"\", \"Actor1EthnicCode\": \"myn\", \"Actor1Religion1Code\": \"\", \"Actor1Religion2Code\": \"\", \"Actor1Type1Code\": \"\", \"Actor1Type2Code\": \"\", \"Actor1Type3Code\": \"\", \"Actor2Code\": \"\", \"Actor2Name\": \"\", \"Actor2CountryCode\": \"\", \"Actor2KnownGroupCode\": \"\", \"Actor2EthnicCode\": \"\", \"Actor2Religion1Code\": \"\", \"Actor2Religion2Code\": \"\", \"Actor2Type1Code\": \"\", \"Actor2Type2Code\": \"\", \"Actor2Type3Code\": \"\", \"IsRootEvent\": \"No\", \"EventCode\": \"Criticize or denounce\", \"EventBaseCode\": \"Criticize or denounce\", \"EventRootCode\": \"Disapprove\", \"QuadClass\": \"Verbal Conflict\", \"GoldsteinScale\": \"-2.0\", \"NumMentions\": \"10\", \"NumSources\": \"1\", \"NumArticles\": \"10\", \"AvgTone\": \"-4.15667466027178\", \"Actor1Geo_Type\": \"1\", \"Actor1Geo_Fullname\": \"Guatemala\", \"Actor1Geo_CountryCode\": \"GT\", \"Actor1Geo_ADM1Code\": \"GT\", \"Actor1Geo_ADM2Code\": \"\", \"Actor1Geo_Lat\": \"15.5\", \"Actor1Geo_Long\": \"-90.25\", \"Actor1Geo_FeatureID\": \"GT\", \"Actor2Geo_Type\": \"0\", \"Actor2Geo_Fullname\": \"\", \"Actor2Geo_CountryCode\": \"\", \"Actor2Geo_ADM1Code\": \"\", \"Actor2Geo_ADM2Code\": \"\", \"Actor2Geo_Lat\": \"\", \"Actor2Geo_Long\": \"\", \"Actor2Geo_FeatureID\": \"\", \"ActionGeo_Type\": \"1\", \"ActionGeo_Fullname\": \"Guatemala\", \"ActionGeo_CountryCode\": \"GT\", \"ActionGeo_ADM1Code\": \"GT\", \"ActionGeo_ADM2Code\": \"\", \"ActionGeo_Lat\": \"15.5\", \"ActionGeo_Long\": \"-90.25\", \"ActionGeo_FeatureID\": \"GT\", \"DATEADDED\": \"20230306221500\", \"SOURCEURL\": \"https://www.elmercuriodigital.net/2023/03/con-rebeldia-germinamos-el-feminismo.html\", \"ActionGeo_Location\": [-90.25, 15.5], \"Actor1Geo_Location\": [-90.25, 15.5]}"
    ],
    "event.original.keyword": [
        "{\"GlobalEventID\": \"1088025774\", \"Day\": \"20230306\", \"MonthYear\": \"202303\", \"Year\": \"2023\", \"FractionDate\": \"2023.1808\", \"Actor1Code\": \"myn\", \"Actor1Name\": \"MAYAN\", \"Actor1CountryCode\": \"\", \"Actor1KnownGroupCode\": \"\", \"Actor1EthnicCode\": \"myn\", \"Actor1Religion1Code\": \"\", \"Actor1Religion2Code\": \"\", \"Actor1Type1Code\": \"\", \"Actor1Type2Code\": \"\", \"Actor1Type3Code\": \"\", \"Actor2Code\": \"\", \"Actor2Name\": \"\", \"Actor2CountryCode\": \"\", \"Actor2KnownGroupCode\": \"\", \"Actor2EthnicCode\": \"\", \"Actor2Religion1Code\": \"\", \"Actor2Religion2Code\": \"\", \"Actor2Type1Code\": \"\", \"Actor2Type2Code\": \"\", \"Actor2Type3Code\": \"\", \"IsRootEvent\": \"No\", \"EventCode\": \"Criticize or denounce\", \"EventBaseCode\": \"Criticize or denounce\", \"EventRootCode\": \"Disapprove\", \"QuadClass\": \"Verbal Conflict\", \"GoldsteinScale\": \"-2.0\", \"NumMentions\": \"10\", \"NumSources\": \"1\", \"NumArticles\": \"10\", \"AvgTone\": \"-4.15667466027178\", \"Actor1Geo_Type\": \"1\", \"Actor1Geo_Fullname\": \"Guatemala\", \"Actor1Geo_CountryCode\": \"GT\", \"Actor1Geo_ADM1Code\": \"GT\", \"Actor1Geo_ADM2Code\": \"\", \"Actor1Geo_Lat\": \"15.5\", \"Actor1Geo_Long\": \"-90.25\", \"Actor1Geo_FeatureID\": \"GT\", \"Actor2Geo_Type\": \"0\", \"Actor2Geo_Fullname\": \"\", \"Actor2Geo_CountryCode\": \"\", \"Actor2Geo_ADM1Code\": \"\", \"Actor2Geo_ADM2Code\": \"\", \"Actor2Geo_Lat\": \"\", \"Actor2Geo_Long\": \"\", \"Actor2Geo_FeatureID\": \"\", \"ActionGeo_Type\": \"1\", \"ActionGeo_Fullname\": \"Guatemala\", \"ActionGeo_CountryCode\": \"GT\", \"ActionGeo_ADM1Code\": \"GT\", \"ActionGeo_ADM2Code\": \"\", \"ActionGeo_Lat\": \"15.5\", \"ActionGeo_Long\": \"-90.25\", \"ActionGeo_FeatureID\": \"GT\", \"DATEADDED\": \"20230306221500\", \"SOURCEURL\": \"https://www.elmercuriodigital.net/2023/03/con-rebeldia-germinamos-el-feminismo.html\", \"ActionGeo_Location\": [-90.25, 15.5], \"Actor1Geo_Location\": [-90.25, 15.5]}"
    ],
    "EventBaseCode": [
        "Criticize or denounce"
    ],
    "EventBaseCode.keyword": [
        "Criticize or denounce"
    ],
    "EventCode": [
        "Criticize or denounce"
    ],
    "EventCode.keyword": [
        "Criticize or denounce"
    ],
    "EventRootCode": [
        "Disapprove"
    ],
    "EventRootCode.keyword": [
        "Disapprove"
    ],
    "FractionDate": [
        2023.1808
    ],
    "GlobalEventID": [
        1088025774
    ],
    "GoldsteinScale": [
        -2
    ],
    "IsRootEvent": [
        "No"
    ],
    "IsRootEvent.keyword": [
        "No"
    ],
    "MonthYear": [
        202303
    ],
    "NumArticles": [
        10
    ],
    "NumMentions": [
        10
    ],
    "NumSources": [
        1
    ],
    "QuadClass": [
        "Verbal Conflict"
    ],
    "QuadClass.keyword": [
        "Verbal Conflict"
    ],
    "SOURCEURL": [
        "https://www.elmercuriodigital.net/2023/03/con-rebeldia-germinamos-el-feminismo.html"
    ],
    "SOURCEURL.keyword": [
        "https://www.elmercuriodigital.net/2023/03/con-rebeldia-germinamos-el-feminismo.html"
    ],
    "Year": [
        2023
    ],
}

# %%
future = producer.send('gdelt', event) 
result = future.get(timeout=60)

# %%
result
# Out:
# RecordMetadata(topic='gdelt', partition=0, topic_partition=TopicPartition(topic='gdelt', partition=0), offset=0, timestamp=1678207532378, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=6405, serialized_header_size=-1)
